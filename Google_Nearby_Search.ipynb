# %%
# Dependencies and Setup
import requests
import gmaps
import json
# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

print(json.dumps(hotels, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uECopC-YRUww7CZ3_o9z1p3nNfWv9w78eXXUt1XVtrDatTMfAk0zA6t58F5_1SX3MvcT1MNSzPPSGHRJopZm0T0x-PVaV1f6Uhu_kYf5gH_oMYyNzsDHabHjKzbINGRn_hmenG4oEy6vZKSXFeoP5GcmVexoBe-7gNi6IB7jAL1bYuOTlS85uKZqTr919gvtpP8eEgSEEdY5iURP0P5fx_yEFttcJqwybXNqsgHZMROT5ptPWORxf-EhJpSy_rL0EWPOwQmaqF5UbOv3ieU_eJlucWII0gD_BnIpPrbxK65g_L7oPYyaPUZuYhV2KQW9dAES56rbCMQly-XrNeFzM9Iyn2rNMCLlqNPbFFrih92sEOmls7AzaZuYluSVRg-8a7eME1Xu9nOyviEJ033nmrMhklWs_JJN56Ke7_kpP8PbWjC4XC2XIyq5",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8581126,
#                     "lng": 2.3529277
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8594360302915,
#                         "lng": 2.354355480291502
#                     },
#                     "southwest": {
#                         "lat": 48.8567380697085,
#                         "lng": 2.351657519708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Duo",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107554201425443337224\">H\u00f4tel Duo</a>"
#                     ],
#                     "photo_reference": "Aap_uEAq47UWs0yHUCMgN2gXokrwwOGffsFQcMBKMYBSynvF9GquTpltpXKUhDBcOOCp3rLIZncI-JBArBWL5rVsLSP4EYtdgUd3Rpz-G5vQfAF-4UWD5wA2-LH2wiaoG2jHA5x1gqdHvV3yBVJDN0xc7_CxpNl2ppqv8dk-iLOxzWt3gkP3",
#                     "width": 5760
#                 }
#             ],
#             "place_id": "ChIJWU9CqB1u5kcR5P1F2SMoJmc",
#             "plus_code": {
#                 "compound_code": "V953+65 Paris, France",
#                 "global_code": "8FW4V953+65"
#             },
#             "rating": 4.2,
#             "reference": "ChIJWU9CqB1u5kcR5P1F2SMoJmc",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "spa",
#                 "lodging",
#                 "bar",
#                 "gym",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 299,
#             "vicinity": "11 Rue du Temple, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8582861,
#                     "lng": 2.3464944
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.85954748029151,
#                         "lng": 2.347782830291502
#                     },
#                     "southwest": {
#                         "lat": 48.85684951970851,
#                         "lng": 2.345084869708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Britannique - Paris Centre",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1426,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108984000175492464929\">H\u00f4tel Britannique - Paris Centre</a>"
#                     ],
#                     "photo_reference": "Aap_uEC1wK-PaXC7_Aouchwn_nrPq_1e4yUKs_1NgOMb34fHdm8vst1VlhoC0qyOCGko5ogvZKg1xTaQzO6j-RbQ5mLGd2IopEMWx5rb-Xw4Es316IRn-JcEh2nFJwe0WXZJYDOwNDQeIPXw2yxYAw_hLVyr13qbcVloYE_PqhZ1XYPdEcXE",
#                     "width": 1476
#                 }
#             ],
#             "place_id": "ChIJ-4Siox9u5kcRm9vM6DcMXyU",
#             "plus_code": {
#                 "compound_code": "V85W+8H Paris, France",
#                 "global_code": "8FW4V85W+8H"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ-4Siox9u5kcRm9vM6DcMXyU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 622,
#             "vicinity": "20 Avenue Victoria, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8606655,
#                     "lng": 2.3469293
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8617653302915,
#                         "lng": 2.348020880291502
#                     },
#                     "southwest": {
#                         "lat": 48.85906736970851,
#                         "lng": 2.345322919708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Citadines Les Halles Paris",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 849,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102565262508115704337\">Citadines Les Halles Paris (Apart hotel Paris)</a>"
#                     ],
#                     "photo_reference": "Aap_uEBZYuTQXpmFDy531NgB3HO6Ku7V9vJ6gVrk3OsRGuV_YcWYyMmRs6A6lRr9_yajw8xn-4AwBAmJYBOa0nAjSLeSfUiTzjbCGiW7alTk4A5cBG3JEOejafU_Y_C0zBSUNxwZOSK3LHSK40gZkCpyqUPDwOEUSaXVAcLwzauE4x1d1D9R",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJQ_QDrxhu5kcRJzNxLLEOSfU",
#             "plus_code": {
#                 "compound_code": "V86W+7Q Paris, France",
#                 "global_code": "8FW4V86W+7Q"
#             },
#             "rating": 4.1,
#             "reference": "ChIJQ_QDrxhu5kcRJzNxLLEOSfU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 860,
#             "vicinity": "4 Rue des Innocents, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8607658,
#                     "lng": 2.3465318
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8620584302915,
#                         "lng": 2.347692880291501
#                     },
#                     "southwest": {
#                         "lat": 48.85936046970851,
#                         "lng": 2.344994919708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Novotel Paris Les Halles",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111815616573299411056\">Novotel Paris Les Halles</a>"
#                     ],
#                     "photo_reference": "Aap_uEAyIJyoMdnBctYOfcVuuTGp9JNyuZ8Nw_4M_Uz8-W3o1YfnenhBUmRhjkdbFeWnIO3uXmiXHcgkCfyzRuxw1UjBVcWZP_-airnWtuIKtWqDoNraZTQOsI412s1DH5Zj1PrcdMGsb5PvH2GpoiDGWX50PJSBAo4OatHacsPbd7ILLVWq",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJGW2pNx9u5kcRI3oyL8NG5BQ",
#             "plus_code": {
#                 "compound_code": "V86W+8J Paris, France",
#                 "global_code": "8FW4V86W+8J"
#             },
#             "rating": 4.4,
#             "reference": "ChIJGW2pNx9u5kcRI3oyL8NG5BQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2238,
#             "vicinity": "8 Place Marguerite de Navarre, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.860352,
#                     "lng": 2.3440948
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.86165553029149,
#                         "lng": 2.345549080291502
#                     },
#                     "southwest": {
#                         "lat": 48.8589575697085,
#                         "lng": 2.342851119708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Ducs de Bourgogne",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1390,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101411638353598558320\">H\u00f4tel Ducs de Bourgogne</a>"
#                     ],
#                     "photo_reference": "Aap_uED8iX-M0ZCRJWTZmJ2XDsyEXwdqscDyVRi82PTHJ8YpFzF8hkinJg4jsF2mwFaZbGtCXsozT43lbNCiFw-9FFuPiUAcFy-OHE1rHMtGQc7ZoQ5Ny1oFfYrX6pwjR3qb-w0G8vN9WIDKLD2SPE2-RtBXQFpV945P_H0XuIPttUGPbqgZ",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJifTG5yFu5kcRdnisbwxnAx4",
#             "plus_code": {
#                 "compound_code": "V86V+4J Paris, France",
#                 "global_code": "8FW4V86V+4J"
#             },
#             "rating": 4.5,
#             "reference": "ChIJifTG5yFu5kcRdnisbwxnAx4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 279,
#             "vicinity": "19 Rue du Pont Neuf, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8555091,
#                     "lng": 2.3408736
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8569076302915,
#                         "lng": 2.342319280291502
#                     },
#                     "southwest": {
#                         "lat": 48.8542096697085,
#                         "lng": 2.339621319708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Citadines Saint-Germain-des-Pr\u00e9s Paris (Apart hotel Paris)",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113188832595116816387\">Citadines Saint-Germain-des-Pr\u00e9s Paris</a>"
#                     ],
#                     "photo_reference": "Aap_uEA-fKZyGgzlmGD45Kl_rMf7UPdljWifiFOFQvoNKSvTEbOTKrASO_4BqDGTMn0UYtoO1PhP62aCQK6Om4WZ1EJYlF4ECq8RMi7CLgA_9-7OqbG_WD-ROkBTQUwkQ9fWEQzfEaca_2NoIhdqtLfEHMFhBP79I9i-qTSBnjJ52PXq6nrt",
#                     "width": 6720
#                 }
#             ],
#             "place_id": "ChIJo5pYcN9x5kcRERXdocMgqmE",
#             "plus_code": {
#                 "compound_code": "V84R+68 Paris, France",
#                 "global_code": "8FW4V84R+68"
#             },
#             "rating": 4.3,
#             "reference": "ChIJo5pYcN9x5kcRERXdocMgqmE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 705,
#             "vicinity": "53 ter Quai des Grands Augustins, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8663519,
#                     "lng": 2.3606461
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.86775308029149,
#                         "lng": 2.361905130291502
#                     },
#                     "southwest": {
#                         "lat": 48.8650551197085,
#                         "lng": 2.359207169708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Paris France H\u00f4tel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2673,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102332962500946068613\">Paris France H\u00f4tel</a>"
#                     ],
#                     "photo_reference": "Aap_uED1R58XjDtMtKxtjb_Zp1pHU1gB7IIObIoPK6R-_QUP7XZUb86CD2fzTAR3PEaL_4w_3NJs4HA-3cfCA_UrC2G4CmDJbXPKouFNXexxd1h99C-ngUI1cW9gIpY8NjT46lvIQYGl56tGNRxNYudfnSEhmeLjNDPenta3Hq8pHzf_8OL4",
#                     "width": 3463
#                 }
#             ],
#             "place_id": "ChIJhXWLZg9u5kcRDVyqoZYgcmg",
#             "plus_code": {
#                 "compound_code": "V986+G7 Paris, France",
#                 "global_code": "8FW4V986+G7"
#             },
#             "rating": 4.3,
#             "reference": "ChIJhXWLZg9u5kcRDVyqoZYgcmg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 385,
#             "vicinity": "72 Rue de Turbigo, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.86386539999999,
#                     "lng": 2.3325488
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8650759802915,
#                         "lng": 2.333775730291502
#                     },
#                     "southwest": {
#                         "lat": 48.8623780197085,
#                         "lng": 2.331077769708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Hotel Regina Louvre",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3700,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109908333790946649027\">H\u00f4tel Regina Louvre</a>"
#                     ],
#                     "photo_reference": "Aap_uEAVdYuu-SEq9R59lM4Gy_mjyyBSgwS7inACysY4zXIa2Yf2tXLbXbM9GPkoNApCbTbpwIRy5QCLy4swnPNTyQThtO3WUoKGvjAWmGYh-NdvQGa-BsPD3OA-cIJX4FOhLpe8uT0QC2ZJhFSbkMmIBMqFDZFEWPI5QL0E995tA4FsUL68",
#                     "width": 5550
#                 }
#             ],
#             "place_id": "ChIJP_-HCS9u5kcRsj9b1x7Pl8w",
#             "plus_code": {
#                 "compound_code": "V87M+G2 Paris, France",
#                 "global_code": "8FW4V87M+G2"
#             },
#             "rating": 4.4,
#             "reference": "ChIJP_-HCS9u5kcRsj9b1x7Pl8w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 508,
#             "vicinity": "2 Place des Pyramides, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.84795229999999,
#                     "lng": 2.370869
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8492035302915,
#                         "lng": 2.372290080291501
#                     },
#                     "southwest": {
#                         "lat": 48.8465055697085,
#                         "lng": 2.369592119708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "ibis Paris Gare de Lyon Ledru Rollin 12\u00e8me",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101181280085797863615\">Kevin Nguyen</a>"
#                     ],
#                     "photo_reference": "Aap_uEBsRgL3ikGayZ5cTDsjnJ-9wiqHk8uEJodwvA2CwbNCFmsh4tracyhNetHPNWmswvsmTLBAh3NWujdx-cg-aRWseYmzFUUr32Nm0yfkaNpQILx4qDo0Z2yLQ2fsxM-rycPSS4rNlUH8SaPONp4MaeT0TPQiP5SaQUpMm1DrvUzO-cD2",
#                     "width": 1536
#                 }
#             ],
#             "place_id": "ChIJ9RNxcQNy5kcRnZJ4vsuXcow",
#             "plus_code": {
#                 "compound_code": "R9XC+58 Paris, France",
#                 "global_code": "8FW4R9XC+58"
#             },
#             "rating": 4,
#             "reference": "ChIJ9RNxcQNy5kcRnZJ4vsuXcow",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 832,
#             "vicinity": "41/43 Avenue Ledru Rollin, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8710647,
#                     "lng": 2.34991
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.87241888029151,
#                         "lng": 2.351188530291502
#                     },
#                     "southwest": {
#                         "lat": 48.86972091970851,
#                         "lng": 2.348490569708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel des Com\u00e9dies Paris",
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114696623290303183213\">Noble</a>"
#                     ],
#                     "photo_reference": "Aap_uEAp3kUkAnRy3f2M0uh7AcPRqQhLfeuXg8z45D2UnmzA26nFbqstO8v4AGw_Nn0IgFO3xrvqGF2rkBJ1PiFJF5AxAjejTsO9NzeWsj1e8ceq8wv3EGQN9uNteGCwq_AWJuVfXdXRv64m4GQ4Ziz1lzduXNbDVq4Cm42pgeaYUidfrRTv",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJn6ginxZu5kcRmAEK0OHm0cI",
#             "plus_code": {
#                 "compound_code": "V8CX+CX Paris, France",
#                 "global_code": "8FW4V8CX+CX"
#             },
#             "rating": 4.2,
#             "reference": "ChIJn6ginxZu5kcRmAEK0OHm0cI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 195,
#             "vicinity": "8 Rue d'Hauteville, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.84754640000001,
#                     "lng": 2.3718722
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8488750302915,
#                         "lng": 2.373125480291502
#                     },
#                     "southwest": {
#                         "lat": 48.8461770697085,
#                         "lng": 2.370427519708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel De France Gare de Lyon Bastille",
#             "photos": [
#                 {
#                     "height": 787,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117462031751048846575\">H\u00f4tel De France Gare de Lyon Bastille</a>"
#                     ],
#                     "photo_reference": "Aap_uEDv0RtEIhH1_YlBTmIEwKgjeB_M6ULXb37EF6kvW-QuusAOGzf8j6H5yRIbaLPEp9btvlsvvu9e7oiZPOD-KowFJP72cHTOoeaGBPEaPu_5vsQOJF_Gpop-6m1oomjw1ygh2rJjBWEqwM6hvcr7vCTzL8yfGuqUC8VBESGym_XZ8T_A",
#                     "width": 1181
#                 }
#             ],
#             "place_id": "ChIJz6DBYgNy5kcRhOu1LhDIECM",
#             "plus_code": {
#                 "compound_code": "R9XC+2P Paris, France",
#                 "global_code": "8FW4R9XC+2P"
#             },
#             "rating": 3.3,
#             "reference": "ChIJz6DBYgNy5kcRhOu1LhDIECM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 381,
#             "vicinity": "12 Rue de Lyon, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8717386,
#                     "lng": 2.3447052
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8731374802915,
#                         "lng": 2.346059980291502
#                     },
#                     "southwest": {
#                         "lat": 48.8704395197085,
#                         "lng": 2.343362019708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Pr\u00e9lude Op\u00e9ra Paris",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 5120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113098608949799179620\">Chrystelle Baudry</a>"
#                     ],
#                     "photo_reference": "Aap_uEAc3Ab6Iei_PQROOcsGIHZqyUYYE-ykWBmtNBn5Uk5aU_DNZm5H4uyhOyiK8BMl8Gw44dKgRpe7JZWceJYLZqlPvVDjDp5Xp6FcFGtk2zu6qMxtSHlDTVFSIghLftIIGLyWoH_ZUYbPAOC6PdxomeCJ5eXaueiXDtpd9zVYIfD8cSuf",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJ8e3Qcj5u5kcR2MIGwNxustk",
#             "plus_code": {
#                 "compound_code": "V8CV+MV Paris, France",
#                 "global_code": "8FW4V8CV+MV"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ8e3Qcj5u5kcR2MIGwNxustk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 373,
#             "vicinity": "8 Cit\u00e9 Berg\u00e8re, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8423491,
#                     "lng": 2.3632246
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8436624802915,
#                         "lng": 2.364708880291502
#                     },
#                     "southwest": {
#                         "lat": 48.8409645197085,
#                         "lng": 2.362010919708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Libertel Austerlitz Jardin des Plantes",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114802271282641766772\">H\u00f4tel Libertel Austerlitz Jardin des Plantes</a>"
#                     ],
#                     "photo_reference": "Aap_uECG8PqsNynHq9pRJcyJutKgmcLfEklrOdpAxS0xTcxJ8xDEKjy2CunKebdTLG3IxQ5ZabAgTau-MqhPkPgvDc3Cn5_1Cg1ZQOiRJ9qv0DCSB8rILKvZ27Kt02Y9hI5tFHtnebysLTZSlCwGltbJcqg6FJ2ghHiOvkX9qQnk_TdsdvD0",
#                     "width": 6720
#                 }
#             ],
#             "place_id": "ChIJe-udXPZx5kcRKURHNFv5BSw",
#             "plus_code": {
#                 "compound_code": "R9R7+W7 Paris, France",
#                 "global_code": "8FW4R9R7+W7"
#             },
#             "rating": 4,
#             "reference": "ChIJe-udXPZx5kcRKURHNFv5BSw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 440,
#             "vicinity": "12 Boulevard de l'H\u00f4pital, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8642974,
#                     "lng": 2.3308142
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8655789302915,
#                         "lng": 2.332153980291502
#                     },
#                     "southwest": {
#                         "lat": 48.8628809697085,
#                         "lng": 2.329456019708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Saint James Albany Paris H\u00f4tel Spa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 400,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108570400659068256718\">Saint James Albany Paris H\u00f4tel Spa</a>"
#                     ],
#                     "photo_reference": "Aap_uEA94RLkMuatQAiPgBgxLNnokMQ2qWV5OLmqORgA6O66E2pH63WJJbLZxD8aG8dRaJcINtrWOzueqnl6W3vcQvcwCWr2OadwKJQgat1jx_gV1ueuGD3a8EpwqdeQE0v1jGRrrt6afqezH6YFc1Olth2FkXWsaoVXbtkBKpMUgrXOa4xr",
#                     "width": 600
#                 }
#             ],
#             "place_id": "ChIJ8znTVS5u5kcREq8TmzOICFs",
#             "plus_code": {
#                 "compound_code": "V87J+P8 Paris, France",
#                 "global_code": "8FW4V87J+P8"
#             },
#             "rating": 4,
#             "reference": "ChIJ8znTVS5u5kcREq8TmzOICFs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1075,
#             "vicinity": "202 Rue de Rivoli, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.87110329999999,
#                     "lng": 2.3389728
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8724588802915,
#                         "lng": 2.340112930291502
#                     },
#                     "southwest": {
#                         "lat": 48.8697609197085,
#                         "lng": 2.337414969708499
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Ic\u00f4ne",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1066,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108137830440312077288\">H\u00f4tel Ic\u00f4ne</a>"
#                     ],
#                     "photo_reference": "Aap_uEBK3hBncm-ixxsQYj2-iQfOB8kI0yuuOS9GrvZ1wasze7Sd4kyi2_aCn0WiRn_e7lBEbW7xFV_PJAfwh3oIWBk5KL422aSBLIp43G_-49Mk9suK_kvzaf90IkOWpEPef9CaQEWdQxZgRGQ2hldIzNt7G3tSIsKcA2Bc5Pl2GYMS-R74",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJpQvq5Dtu5kcR0COam2f7v_I",
#             "plus_code": {
#                 "compound_code": "V8CQ+CH Paris, France",
#                 "global_code": "8FW4V8CQ+CH"
#             },
#             "rating": 3.7,
#             "reference": "ChIJpQvq5Dtu5kcR0COam2f7v_I",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 141,
#             "vicinity": "4 Rue d'Amboise, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8524547,
#                     "lng": 2.3472064
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8538838802915,
#                         "lng": 2.348601530291502
#                     },
#                     "southwest": {
#                         "lat": 48.8511859197085,
#                         "lng": 2.345903569708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Esmeralda",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114852001362047630790\">Georgia Hentze</a>"
#                     ],
#                     "photo_reference": "Aap_uED38NPx2BPbYLlTFls_gGgiygl4qi-7gBhOTSH8C0Wa6TjSJFH5YWGKeVBVc0mJV-6hv7wmDv90xF20LyQDNn5myuDogVKxf4KFw3Jd8PXnLLPLfl1wR6gCW3cviW34XmXlb_ttBSG2tAY1ZeNX1lE2XqaTNUnHgq5g8ptXIYIlKtTK",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJO_g_H-Fx5kcRmaabUHA3dT4",
#             "plus_code": {
#                 "compound_code": "V82W+XV Paris, France",
#                 "global_code": "8FW4V82W+XV"
#             },
#             "rating": 4.1,
#             "reference": "ChIJO_g_H-Fx5kcRmaabUHA3dT4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 146,
#             "vicinity": "4 Rue Saint-Julien le Pauvre, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8530901,
#                     "lng": 2.3447174
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8544403302915,
#                         "lng": 2.346001280291502
#                     },
#                     "southwest": {
#                         "lat": 48.8517423697085,
#                         "lng": 2.343303319708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Albe Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117571951379278191466\">Albe Hotel Saint Michel</a>"
#                     ],
#                     "photo_reference": "Aap_uEBOuy5okyubEwPwhWrvo_IH2L_fGjOOW2O22MoPvFh-mmFM4Yt9c2gSwEC5Y5j3lqsWGUf9SH1xRHfmEzAgMIngQG-4Cg48olHvlILnW7yOztAj0UsBiP-FDyfnvXx_n-CdmaomSyOisLES1kFEBn65rYys-ZdnFmuQj7844qO-fVen",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJ8R5-hOBx5kcRsCOdfj8GLeY",
#             "plus_code": {
#                 "compound_code": "V83V+6V Paris, France",
#                 "global_code": "8FW4V83V+6V"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ8R5-hOBx5kcRsCOdfj8GLeY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 331,
#             "vicinity": "1 Rue de la Harpe, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8499443,
#                     "lng": 2.3462474
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8512737302915,
#                         "lng": 2.347507380291502
#                     },
#                     "southwest": {
#                         "lat": 48.8485757697085,
#                         "lng": 2.344809419708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Home Latin",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108547915404801536469\">Jp Homma</a>"
#                     ],
#                     "photo_reference": "Aap_uEDm7nI62PS4dFkmvE2t-DnRQf9iy4gWWaKsO_YrmYVkKkpILN9jWexfAaH3UiZeh0GgsIXcCD57x5Z6kODXDo9Lcgda20f2iE-2Xcf6hsvKx2gFX22BxqmESffrBN-JUw2C-1IXeB_XZrXE0TmApFPgZSXQgPGVgZxtlqvCHzkqvRXT",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJMWNDIudx5kcRupjNdNDYKkw",
#             "plus_code": {
#                 "compound_code": "R8XW+XF Paris, France",
#                 "global_code": "8FW4R8XW+XF"
#             },
#             "rating": 3.5,
#             "reference": "ChIJMWNDIudx5kcRupjNdNDYKkw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 285,
#             "vicinity": "15-17 Rue du Sommerard, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.85473870000001,
#                     "lng": 2.3395455
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8561127802915,
#                         "lng": 2.340820530291502
#                     },
#                     "southwest": {
#                         "lat": 48.8534148197085,
#                         "lng": 2.338122569708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel d'Aubusson",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2174,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115702439863948549296\">H\u00f4tel d&#39;Aubusson Paris</a>"
#                     ],
#                     "photo_reference": "Aap_uEDXOa9xvQ3Hb1oVcY19Vh_JkyyDrI551cfbQpK2ingb3oU3ncPZY9g-8U2a9O1lk9KcwYc58oOD8M8-FP3Cb7vF9yzIXMmb-8eHBzIErKUJ8BczpYaj7tu_aNopRZetdlbDPtmieofstm9QfxKNAlOnoXkjWjbCFhbYbrFYJ1kWm9B2",
#                     "width": 1739
#                 }
#             ],
#             "place_id": "ChIJk6ztMN9x5kcREpQ8edWOs7E",
#             "plus_code": {
#                 "compound_code": "V83Q+VR Paris, France",
#                 "global_code": "8FW4V83Q+VR"
#             },
#             "rating": 4.7,
#             "reference": "ChIJk6ztMN9x5kcREpQ8edWOs7E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 293,
#             "vicinity": "33 Rue Dauphine, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.85184049999999,
#                     "lng": 2.3448082
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8531470802915,
#                         "lng": 2.346121880291502
#                     },
#                     "southwest": {
#                         "lat": 48.8504491197085,
#                         "lng": 2.343423919708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel 4 \u00e9toiles Parc Saint S\u00e9verin Paris 5\u00e8me - Esprit de France",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2362,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107542132357877294567\">H\u00f4tel 4 \u00e9toiles Parc Saint S\u00e9verin Paris 5\u00e8me - Esprit de France</a>"
#                     ],
#                     "photo_reference": "Aap_uEDpXf-Jhc_tdrzLTSrtd1bRH9GG3Z4gtecE7MeRv6lkL_m8pVMZKcsexYe2Oso0b9Jo36E8Z8TjqGph8k0CDRtEoVTLSQqenPRRJ5YTPIliRN3VXmj4K6aCKfc16ss1dpvNlZLXo8Nkagb1JXhWDzRs3XWpQCKFpTmjnx7gA4janii6",
#                     "width": 3776
#                 }
#             ],
#             "place_id": "ChIJ9--kuuBx5kcRojwQ1yEK2cY",
#             "plus_code": {
#                 "compound_code": "V82V+PW Paris, France",
#                 "global_code": "8FW4V82V+PW"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ9--kuuBx5kcRojwQ1yEK2cY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 140,
#             "vicinity": "22 Rue de la Parcheminerie, Paris"
#         }
#     ],
#     "status": "OK"
# }

# %%
len(hotels["results"])
# Out:
# 20

# %%
hotels['results'][0]['name']
# Out:
# 'Hôtel Duo'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c33499b5a739> in <module>
#       1 # Iterate through the DataFrame.
# ----> 2 for index, row in hotel_df.iterrows():
#       3     # Get the latitude and longitude.
#       4     lat = row["Lat"]
#       5     lng = row["Lng"]
#
# NameError: name 'hotel_df' is not defined
